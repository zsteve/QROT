# %%
using Pkg
Pkg.activate(".")
using OptimalTransport
using LinearAlgebra
using SparseArrays
using Distances
using NNlib
using Plots
using Random

include("../../src/util.jl")
# Out:
#   Activating project at `/data/gpfs/projects/punim0638/stephenz/QROT/notebooks/ex_algs`
# norm_kernel (generic function with 1 method)

# %%
function P1(X)
    n = size(X, 1)
    X + ((1/n) * I + (sum(X)/n^2)*I - (1/n)*X) * one.(X) - (1/n)*one.(X)*X
end

function P2(X)
    relu.(X)
end

function proj_l2_alternating(A; max_iter = 250, print_iter = 25, save_trace = false)
    trace = []
    X = copy(A)
    for i = 1:max_iter
        X .= P1(X)
        if minimum(X) >= 0
            break
        end
        X .= P2(X)
        if i % print_iter == 0
            err = norm(sum(X; dims = 1) .- 1, 2)
            if save_trace push!(trace, err) end
            @info "Iteration $(i), marginal error $err"
        end
    end
    return symm(X), trace
end

function proj_l2_newton(A; rtol = 1e-6, atol = 1e-6, maxiter = 100, kwargs...)
    C = (ones(size(A, 1)) * ones(size(A, 2))') - A
    solver = OptimalTransport.build_solver(ones(size(A, 1)), C, 1, OptimalTransport.SymmetricQuadraticOTNewton(0.1, 0.5, 1.0e-9, 250); maxiter = maxiter, atol = atol, rtol = rtol, kwargs...)
    OptimalTransport.solve!(solver)
    A = symm(OptimalTransport.plan(solver))
    return A
end
# Out:
# proj_l2_newton (generic function with 1 method)

# %%
N = 250
Random.seed!(0)
A = symm(randn(N, N));

# %%
@time X, trace = proj_l2_alternating(A; max_iter = 2_500, save_trace = true);
# Out:
# [ Info: Iteration 25, marginal error 42.5625049656523
# [ Info: Iteration 50, marginal error 15.875323657868813
# [ Info: Iteration 75, marginal error 8.128287562269213
# [ Info: Iteration 100, marginal error 4.786640189613501
# [ Info: Iteration 125, marginal error 3.0462073566048913
# [ Info: Iteration 150, marginal error 2.0413603434008314
# [ Info: Iteration 175, marginal error 1.4252420894145834
# [ Info: Iteration 200, marginal error 1.023533109605207
# [ Info: Iteration 225, marginal error 0.7522090540469307
# [ Info: Iteration 250, marginal error 0.5633287624194523
# [ Info: Iteration 275, marginal error 0.4273802070037368
# [ Info: Iteration 300, marginal error 0.32779620050222136
# [ Info: Iteration 325, marginal error 0.2541765176780714
# [ Info: Iteration 350, marginal error 0.19895339249637806
# [ Info: Iteration 375, marginal error 0.15685492517982208
# [ Info: Iteration 400, marginal error 0.12441078822302218
# [ Info: Iteration 425, marginal error 0.09917750917227099
# [ Info: Iteration 450, marginal error 0.07940122083299754
# [ Info: Iteration 475, marginal error 0.06381405800025362
# [ Info: Iteration 500, marginal error 0.05146053592009603
# [ Info: Iteration 525, marginal error 0.0416119922918359
# [ Info: Iteration 550, marginal error 0.033726969036247535
# [ Info: Iteration 575, marginal error 0.02739123651000686
# [ Info: Iteration 600, marginal error 0.02228432023055478
# [ Info: Iteration 1825, marginal error 1.443086264432232e-6
# [ Info: Iteration 1850, marginal error 1.1871155037646427e-6
# [ Info: Iteration 1875, marginal error 9.76555534226912e-7
# [ Info: Iteration 1900, marginal error 8.033486515363484e-7
# [ Info: Iteration 1925, marginal error 6.608672481271188e-7
# [ Info: Iteration 1950, marginal error 5.436599204531383e-7
# [ Info: Iteration 1975, marginal error 4.4724267253412906e-7
# [ Info: Iteration 2000, marginal error 3.679271934799671e-7
# [ Info: Iteration 2025, marginal error 3.026796281150981e-7
# [ Info: Iteration 2050, marginal error 2.490044265699822e-7
# [ Info: Iteration 2075, marginal error 2.0484880794241995e-7
# [ Info: Iteration 2100, marginal error 1.6852418733468251e-7
# [ Info: Iteration 2125, marginal error 1.3864155124757682e-7
# [ Info: Iteration 2150, marginal error 1.1405829677331498e-7
# [ Info: Iteration 2175, marginal error 9.383451380130898e-8
# [ Info: Iteration 2200, marginal error 7.719701922005276e-8
# [ Info: Iteration 2225, marginal error 6.350977998757307e-8
# [ Info: Iteration 2250, marginal error 5.224957847729626e-8
# [ Info: Iteration 2275, marginal error 4.298600024919234e-8
# [ Info: Iteration 2300, marginal error 3.536497118594506e-8
# [ Info: Iteration 2325, marginal error 2.9095215384866892e-8
# [ Info: Iteration 2350, marginal error 2.3937113662599653e-8
# [ Info: Iteration 2375, marginal error 1.9693545738005693e-8
# [ Info: Iteration 2400, marginal error 1.620234715642279e-8
# [ Info: Iteration 2425, marginal error 1.3330112115384529e-8
# [ Info: Iteration 2450, marginal error 1.096709260576813e-8
#   2.990876 seconds (56.91 k allocations: 10.482 GiB, 4.09% gc time)
# [ Info: Iteration 2475, marginal error 9.023001167200703e-9
# [ Info: Iteration 2500, marginal error 7.423560929362709e-9

# %%
@time X_ = proj_l2_newton(A; maxiter = 250, rtol = 1e-6, atol = 1e-6);
# Out:
#   0.010112 seconds (440 allocations: 28.873 MiB)

# %%
get_err(x) = norm(sum(x; dims = 1) .- 1, 2)
trace_newton = [get_err(proj_l2_newton(A; maxiter = i, rtol = 1e-12, atol = 1e-12)) for i = 1:25:250]
# Out:
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (1/1): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (26/26): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (51/51): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (76/76): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (101/101): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (126/126): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (151/151): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (176/176): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (201/201): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# ┌ Warning: OptimalTransport.SymmetricQuadraticOTNewton{Float64, Float64, Float64}(0.1, 0.5, 1.0e-9, 250) (226/226): not converged
# └ @ OptimalTransport ~/.julia/packages/OptimalTransport/p1fRd/src/quadratic_newton_symm.jl:230
# 10-element Vector{Float64}:
#  26.28806431049666
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10
#   6.060223287430235e-10

# %%
plt=plot([5*i for i = 1:length(trace)], trace; yscale = :log10, xscale = :log10, label = "Alternating projection", ylabel = "Marginal violation", marker = :x, color = :red, size = (500, 250), legend = :topright)
plot!([5*i for i = 1:length(trace_newton)], trace_newton; label = "Newton", marker = :^, color = :blue)
savefig(plt, "marginal_violation_vs_iter_N_$N.svg")
plt

# %%
norm(sum(X_; dims = 1) .- 1, 2)
# Out:
# 6.060223287430235e-10

# %%
norm(sum(X; dims = 1) .- 1, 2)
# Out:
# 7.4235604815905046e-9

# %%
norm(X - A, 2)
# Out:
# 174.0913712589293

# %%
norm(X_ - A, 2)
# Out:
# 174.02760833629438
